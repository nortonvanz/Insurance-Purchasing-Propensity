# %%
# Playgroud Series - Binary Classification of Insurance Cross Selling
  # https://www.kaggle.com/competitions/playground-series-s4e7
  # Your Goal: predict which customers respond positively to an automobile insurance offer.
  # Metric: Submissions are evaluated using area under the ROC curve.

# %% [markdown]
# # Improvements (to do)

# %%
#DONE v1 and v2:
# use more data (used 100k on train).  -> DT was practically not improved, even with 1.5M rows on test. Saw an post showing there are many repeated rows on dataset.
    # There are no duplicated rows on test data (11M). Removind 1 feature per time, all of them have many duplicates (downsampling). There was no gain of doing that. (https://www.kaggle.com/competitions/playground-series-s4e7/discussion/517167)
# Plot ROC_AUC curve to compare moodel

#DONE V3:
#Probabilistic approach

#DONE V4:
# tested LogisticRegressionCV and  LogisticRegression + GridSearchCV (fine tuning). -> RF is still superior.

#DONE V5:
# CatBoost wuthout default params

#DONE V6
# Balance CatBoost -> did not imporve
# CatBoost + GridSearchCV -> did not improve
# CatBoost + GridSearchCV of [AutoML Grand Prix] 1st Place Solution (https://www.kaggle.com/code/rohanrao/automl-grand-prix-1st-place-solution) -> did not improve

#DONE V7
# Data Prep/Feature Engeering and Cat Boost of [AutoML Grand Prix] 1st Place Solution (https://www.kaggle.com/code/rohanrao/automl-grand-prix-1st-place-solution)
    # Did not run with 11Mi train rows locally (few mommory). Tried w/ 100k train and full test (needed to submit).
    # User iterations=1000 instead of 5000, and task_type= 'CPU', cause 'GPU' -> Demands NVidea graphics cards w/ CUDA
    # Undestood StratifiedKFold w/ CatBoost cross validation
    # Kaggle public score: 0.884 (best by far!)

#DONE V8:
# Optimize hiperparameters with Scikit Optimize BayesSearchCV
    # Used BayesSearchCV. Got 0.871 on public. Had 0.884 with StratifiedKFold. Looks like its critic on this kind of problem.

#TO DO V9:
#Try using both BayesSearchCV and StratifiedKFold, to improve performance, with pipelines.

#######################
#IMPROVE EDA
# Follow Kaggle notebooks

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
import polars as pl

pd.set_option('display.float_format', lambda x: '%.3f' % x) #pandas decimal places
pd.set_option('max_colwidth', 500) #num of cols to be shown
np.set_printoptions(suppress=True, precision=6)#numpy decimal placese


from sklearn.model_selection       import train_test_split, GridSearchCV, StratifiedKFold#, cross_val_score
from sklearn.preprocessing         import MinMaxScaler #OneHotEncoder  
from sklearn.metrics               import roc_auc_score, roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay
from sklearn.tree                  import DecisionTreeClassifier, plot_tree
from sklearn.ensemble              import RandomForestClassifier
from sklearn.linear_model          import LogisticRegressionCV, LogisticRegression

from catboost                      import CatBoostClassifier, Pool #Numpy downgrade needed: pip install numpy==1.26.4 (from mar/24)
from sklearn.pipeline              import Pipeline
from skopt                         import BayesSearchCV, space

# #import sweetviz as sv
# from yellowbrick.features import ParallelCoordinates

# %% [markdown]
# # Load Data

# %%
## load data
#train = pl.read_csv('..\\data\\kaggle\\train.csv')

# Specify the path to your CSV file and read a random sample of the dataset
train = pl.read_csv('..\\data\\kaggle\\train.csv').sample(n=500000)
test = pl.read_csv('..\\data\\kaggle\\test.csv') #.sample(n=70000) needs to be full, cause I neet to submit all the rows!
test = test.with_columns(pl.lit(0).cast(pl.Int64).alias('Response'))

# %%
train[:2]
# Out:
# shape: (2, 12)
# ┌─────────┬────────┬─────┬─────────────────┬───┬────────────────┬──────────────────────┬─────────┬──────────┐
# │ id      ┆ Gender ┆ Age ┆ Driving_License ┆ … ┆ Annual_Premium ┆ Policy_Sales_Channel ┆ Vintage ┆ Response │
# │ ---     ┆ ---    ┆ --- ┆ ---             ┆   ┆ ---            ┆ ---                  ┆ ---     ┆ ---      │
# │ i64     ┆ str    ┆ i64 ┆ i64             ┆   ┆ f64            ┆ f64                  ┆ i64     ┆ i64      │
# ╞═════════╪════════╪═════╪═════════════════╪═══╪════════════════╪══════════════════════╪═════════╪══════════╡
# │ 4960782 ┆ Male   ┆ 24  ┆ 1               ┆ … ┆ 2630.0         ┆ 152.0                ┆ 276     ┆ 0        │
# │ 7810402 ┆ Male   ┆ 63  ┆ 1               ┆ … ┆ 35124.0        ┆ 13.0                 ┆ 77      ┆ 0        │
# └─────────┴────────┴─────┴─────────────────┴───┴────────────────┴──────────────────────┴─────────┴──────────┘

# %%
test[:2]
# Out:
# shape: (2, 12)
# ┌──────────┬────────┬─────┬─────────────────┬───┬────────────────┬──────────────────────┬─────────┬──────────┐
# │ id       ┆ Gender ┆ Age ┆ Driving_License ┆ … ┆ Annual_Premium ┆ Policy_Sales_Channel ┆ Vintage ┆ Response │
# │ ---      ┆ ---    ┆ --- ┆ ---             ┆   ┆ ---            ┆ ---                  ┆ ---     ┆ ---      │
# │ i64      ┆ str    ┆ i64 ┆ i64             ┆   ┆ f64            ┆ f64                  ┆ i64     ┆ i64      │
# ╞══════════╪════════╪═════╪═════════════════╪═══╪════════════════╪══════════════════════╪═════════╪══════════╡
# │ 11504798 ┆ Female ┆ 20  ┆ 1               ┆ … ┆ 2630.0         ┆ 160.0                ┆ 228     ┆ 0        │
# │ 11504799 ┆ Male   ┆ 47  ┆ 1               ┆ … ┆ 37483.0        ┆ 124.0                ┆ 123     ┆ 0        │
# └──────────┴────────┴─────┴─────────────────┴───┴────────────────┴──────────────────────┴─────────┴──────────┘

# %%
## prepare data
df = pl.concat([train, test])

df = df.with_columns([
    pl.col('Gender').replace({'Male': 0, 'Female': 1}).cast(pl.Int32),
    pl.col('Region_Code').cast(int),
    pl.col('Vehicle_Age').replace({'< 1 Year': 0, '1-2 Year': 1, '> 2 Years': 2}).cast(pl.Int32),
    pl.col('Vehicle_Damage').replace({'No': 0, 'Yes': 1}).cast(pl.Int32),
    pl.col('Annual_Premium').cast(int),
    pl.col('Policy_Sales_Channel').cast(int)
])

df = df.with_columns([
    (pl.Series(pd.factorize((df['Previously_Insured'].cast(str) + df['Annual_Premium'].cast(str)).to_numpy())[0])).alias('Previously_Insured_Annual_Premium'),
    (pl.Series(pd.factorize((df['Previously_Insured'].cast(str) + df['Vehicle_Age'].cast(str)).to_numpy())[0])).alias('Previously_Insured_Vehicle_Age'),
    (pl.Series(pd.factorize((df['Previously_Insured'].cast(str) + df['Vehicle_Damage'].cast(str)).to_numpy())[0])).alias('Previously_Insured_Vehicle_Damage'),
    (pl.Series(pd.factorize((df['Previously_Insured'].cast(str) + df['Vintage'].cast(str)).to_numpy())[0])).alias('Previously_Insured_Vintage')
])

train = df[:train.shape[0]].to_pandas()
test = df[train.shape[0]:].to_pandas()

# %%
#convert all cols to lower case, and replace spaces and dots with underscores
train.columns = train.columns.str.replace(' ','_').str.replace('.','_').str.lower()
test.columns = test.columns.str.replace(' ','_').str.replace('.','_').str.lower()

# %%
#Why just interactions with Previously_Insured variable?
    #https://www.kaggle.com/competitions/playground-series-s4e7/discussion/516475#2901376
#-> We ran all combinations of interactions on a smaller subset (500K rows) and chose the Top-3/4 based on feature importance. 
    #Any interaction with Previously_Insured seemed to work the best

# It was on top of feature importance, as seen on other topic:
    #https://www.kaggle.com/competitions/playground-series-s4e7/discussion/516860

#Feature Engeneering with high Feature Importances:
    #https://www.kaggle.com/competitions/playground-series-s4e7/discussion/517112
    #Previously_Insured_Vehicle_Damage
    #Vehicle_Age_Damage

# %%
# PANDAS EQUIVALENT:

# Concatenate train and test DataFrames
# df_pd = pd.concat([train_pd, test_pd], ignore_index=True)

# # Convert specific columns
# df_pd['Gender'] = df_pd['Gender'].replace({'Male': 0, 'Female': 1}).astype('int32')
# df_pd['Region_Code'] = df_pd['Region_Code'].astype(int)
# df_pd['Vehicle_Age'] = df_pd['Vehicle_Age'].replace({'< 1 Year': 0, '1-2 Year': 1, '> 2 Years': 2}).astype('int32')
# df_pd['Vehicle_Damage'] = df_pd['Vehicle_Damage'].replace({'No': 0, 'Yes': 1}).astype('int32')
# df_pd['Annual_Premium'] = df_pd['Annual_Premium'].astype(int)
# df_pd['Policy_Sales_Channel'] = df_pd['Policy_Sales_Channel'].astype(int)

# # Factorize and create new columns  -> pd.factorize() is a function in Pandas that is used to encode categorical (or object) data as integer values.
# df_pd['Previously_Insured_Annual_Premium'] = pd.factorize(df_pd['Previously_Insured'].astype(str) + df_pd['Annual_Premium'].astype(str))[0]
# df_pd['Previously_Insured_Vehicle_Age'] = pd.factorize(df_pd['Previously_Insured'].astype(str) + df_pd['Vehicle_Age'].astype(str))[0]
# df_pd['Previously_Insured_Vehicle_Damage'] = pd.factorize(df_pd['Previously_Insured'].astype(str) + df_pd['Vehicle_Damage'].astype(str))[0]
# df_pd['Previously_Insured_Vintage'] = pd.factorize(df_pd['Previously_Insured'].astype(str) + df_pd['Vintage'].astype(str))[0]

# # Split back into train and test DataFrames
# train_pd = df_pd.iloc[:len(train_pd)]
# test_pd = df_pd.iloc[len(train_pd):]

# # Reset index if needed
# train_pd.reset_index(drop=True, inplace=True)
# test_pd.reset_index(drop=True, inplace=True)

# # Optionally, print or inspect the resulting train_pd and test_pd DataFrames
# print(train_pd.head())
# print(test_pd.head())

# %%
train[:2]
# Out:
#         id  gender  age  driving_license  region_code  previously_insured  \
# 0  4960782       0   24                1           12                   1
# 1  7810402       0   63                1           28                   0
#
#    vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  vintage  \
# 0            0               1            2630                   152      276
# 1            1               1           35124                    13       77
#
#    response  previously_insured_annual_premium  \
# 0         0                                  0
# 1         0                                  1
#
#    previously_insured_vehicle_age  previously_insured_vehicle_damage  \
# 0                               0                                  0
# 1                               1                                  1
#
#    previously_insured_vintage
# 0                           0
# 1                           1

# %%
test[:2]
# Out:
#          id  gender  age  driving_license  region_code  previously_insured  \
# 0  11504798       1   20                1           47                   0
# 1  11504799       0   47                1           28                   0
#
#    vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  vintage  \
# 0            0               0            2630                   160      228
# 1            1               1           37483                   124      123
#
#    response  previously_insured_annual_premium  \
# 0         0                                  3
# 1         0                              13845
#
#    previously_insured_vehicle_age  previously_insured_vehicle_damage  \
# 0                               3                                  3
# 1                               1                                  1
#
#    previously_insured_vintage
# 0                         280
# 1                         381

# %% [markdown]
# # Dataset Split

# %%
#train w/ 500k rows
train[:2]
# Out:
#          id  gender  age  driving_license  region_code  previously_insured  \
# 0   9659161       1   38                1           35                   0
# 1  10037962       0   42                1           46                   0
#
#    vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  vintage  \
# 0            1               1           29095                   124      286
# 1            1               1           28668                   124      160
#
#    response  previously_insured_annual_premium  \
# 0         1                                  0
# 1         1                                  1
#
#    previously_insured_vehicle_age  previously_insured_vehicle_damage  \
# 0                               0                                  0
# 1                               0                                  0
#
#    previously_insured_vintage
# 0                           0
# 1                           1

# %%
X = train.drop(columns="response") 
y = train.response

# %%
#split between train (80%) and test (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 98, stratify = y, test_size = 0.20) #stratify by y

# %%
# train data
print('X_train -> ',X_train.shape)
print('y_train -> ',y_train.shape)
# test data
print('X_test -> ',X_test.shape)
print('y_test -> ',y_test.shape)
# Out:
# X_train ->  (400000, 15)
# y_train ->  (400000,)
# X_test ->  (100000, 15)
# y_test ->  (100000,)

# %% [markdown]
# # ML

# %%
{'classifier__colsample_bylevel': 0.5, 
 'classifier__depth': 7, 
 'classifier__iterations': 1000, 
 'classifier__l2_leaf_reg': 1.0, 
 'classifier__learning_rate': 0.05648875119639046, 
 'classifier__random_strength': 0.5}	


    model = CatBoostClassifier(
        loss_function='Logloss',
        eval_metric='AUC',
        learning_rate=0.05,
        iterations=1000, #5000 original
        depth=9,
        random_strength=0,
        l2_leaf_reg=0.5,
        task_type= 'CPU', #'GPU' -> Demands NVidea graphics cards w/ CUDA
        random_seed=42,
        verbose=False

# %%
#9.1 - How to improve?
    # Set space closer to best params known.
    # Set on fit: early_stopping_rounds=200, to a fast training

# %%
#pipeline approach, combining both BayesSearchCV and StratifiedKFold

# %%
# Define the CatBoostClassifier
catboost_cv = CatBoostClassifier( loss_function='Logloss', 
                                  eval_metric='AUC',  
                                  task_type= 'CPU', #'GPU' -> Demands NVidea graphics cards w/ CUDA)
                                  random_seed=98)

# Define the parameter search space for BayesSearchCV
# search_spaces = {'iterations':       space.Integer(50, 1000), #5000 original
#                 'learning_rate':     space.Real(1e-5, .3, 'log-uniform'),  # 1 × 10−5 -> 0.00001.
#                 'depth':             space.Integer(3, 10),
#                 'l2_leaf_reg':       space.Real(0.2, 10),
#                 'border_count':      space.Integer(32, 254),
#                 'learning_rate':     space.Real(0.01, 1.0),
#                 'scale_pos_weight':  space.Real(1.0, 10.0),
#                 'min_child_samples': space.Integer(1, 100),
#                 'subsample':         space.Real(0.05, 1.0),
#                 'random_strength':   space.Real(0.0, 2.0),
#                 'colsample_bylevel': space.Real(0.5, 1.0)}

# Set space closer to best params known.
search_spaces = {'iterations':       (500, 1000), #5000 original
                'learning_rate':     space.Real(1e-3, .01, 'log-uniform'),  # 1 × 10−5 -> 0.00001.
                'depth':             space.Integer(8, 10),
                'l2_leaf_reg':       space.Real(0.4, 0.6),
                #'border_count':      space.Integer(32, 254),
                'learning_rate':     space.Real(0.01, 0.1),
                #'scale_pos_weight':  space.Real(1.0, 10.0),
                #'min_child_samples': space.Integer(1, 100),
                #'subsample':         space.Real(0.05, 1.0),
                'random_strength':   space.Real(0.0, 0.1)}
                #'colsample_bylevel': space.Real(0.5, 1.0)}

#A StratifiedKFold object is created for 3-fold cross-validation. This method ensures that the class distribution is approximately the same in each fold as in the whole dataset.
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=98)


# Create the pipeline
pipeline = Pipeline([
    ('classifier', catboost_cv)
])

# Create the BayesSearchCV object
bayes_search = BayesSearchCV(
    random_state=98,
    estimator=pipeline,
    search_spaces={'classifier__' + k: v for k, v in search_spaces.items()}, #create a dictionary that maps the hyperparameter names in the param_space dictionary to their corresponding values, but with the prefix classifier__ added to each hyperparameter name.
    n_iter = 10, #how many times the search is performed - default=50
                 #n_iter trades off runtime vs quality of the solution.
                 #Consider increasing n_points if you want to try more parameter settings in parallel.
    n_points = 5, #how many points are sampled in each iteration - default 1
                  #use = 10 first time, to use parallelism max and run fast (> 10 não muda score)
                  #the best result is with n_points = 1, but it is much slower (about 10x +)
    cv=skf,
    #Núum of models = (n_iter * n_points * CV) 
    scoring='roc_auc',
    n_jobs=-1,
    refit = True, # Refit the best estimator with the entire dataset - default=True
    return_train_score = True,
    verbose = 2
)

# Fit the model with BayesSearchCV
bayes_search.fit(X_train, y_train, classifier__early_stopping_rounds=200)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# 0:	total: 75.8ms	remaining: 47.1s
# 1:	total: 137ms	remaining: 42.5s
# 2:	total: 192ms	remaining: 39.6s
# 3:	total: 244ms	remaining: 37.8s
# 4:	total: 301ms	remaining: 37.2s
# 5:	total: 362ms	remaining: 37.3s
# 6:	total: 421ms	remaining: 37.1s
# 7:	total: 484ms	remaining: 37.2s
# 8:	total: 547ms	remaining: 37.3s
# 9:	total: 610ms	remaining: 37.4s
# 10:	total: 672ms	remaining: 37.4s
# 11:	total: 738ms	remaining: 37.6s
# 12:	total: 802ms	remaining: 37.6s
# 13:	total: 877ms	remaining: 38.1s
# 14:	total: 943ms	remaining: 38.2s
# 15:	total: 1.01s	remaining: 38.5s
# 16:	total: 1.08s	remaining: 38.4s
# 17:	total: 1.14s	remaining: 38.3s
# 18:	total: 1.2s	remaining: 38.2s
# 19:	total: 1.26s	remaining: 38.1s
# 20:	total: 1.35s	remaining: 38.6s
# 21:	total: 1.43s	remaining: 39s
# 22:	total: 1.5s	remaining: 39.2s
# 23:	total: 1.57s	remaining: 39.1s
# 24:	total: 1.64s	remaining: 39.2s
# 25:	total: 1.71s	remaining: 39.2s
# 26:	total: 1.78s	remaining: 39.2s
# 27:	total: 1.85s	remaining: 39.2s
# 28:	total: 1.92s	remaining: 39.3s
# 29:	total: 1.98s	remaining: 39.2s
# 30:	total: 2.06s	remaining: 39.3s
# 31:	total: 2.12s	remaining: 39.2s
# 32:	total: 2.2s	remaining: 39.3s
# 33:	total: 2.27s	remaining: 39.3s
# 34:	total: 2.34s	remaining: 39.4s
# 35:	total: 2.41s	remaining: 39.4s
# 36:	total: 2.48s	remaining: 39.3s
# 37:	total: 2.55s	remaining: 39.3s
# 38:	total: 2.62s	remaining: 39.2s
# 39:	total: 2.69s	remaining: 39.2s
# 40:	total: 2.77s	remaining: 39.3s
# 41:	total: 2.85s	remaining: 39.4s
# 42:	total: 2.92s	remaining: 39.3s
# 43:	total: 2.98s	remaining: 39.3s
# 44:	total: 3.05s	remaining: 39.2s
# 45:	total: 3.13s	remaining: 39.2s
# 46:	total: 3.19s	remaining: 39.1s
# 47:	total: 3.27s	remaining: 39.2s
# 48:	total: 3.34s	remaining: 39.1s
# 49:	total: 3.42s	remaining: 39.1s
# 50:	total: 3.48s	remaining: 39s
# 51:	total: 3.54s	remaining: 38.9s
# 52:	total: 3.61s	remaining: 38.8s
# 53:	total: 3.67s	remaining: 38.7s
# 54:	total: 3.74s	remaining: 38.6s
# 55:	total: 3.8s	remaining: 38.5s
# 56:	total: 3.86s	remaining: 38.4s
# 57:	total: 3.93s	remaining: 38.3s
# 58:	total: 4s	remaining: 38.2s
# 59:	total: 4.08s	remaining: 38.3s
# 60:	total: 4.15s	remaining: 38.3s
# 61:	total: 4.21s	remaining: 38.1s
# 62:	total: 4.28s	remaining: 38s
# 63:	total: 4.35s	remaining: 38s
# 64:	total: 4.41s	remaining: 37.9s
# 65:	total: 4.48s	remaining: 37.8s
# 66:	total: 4.55s	remaining: 37.8s
# 67:	total: 4.63s	remaining: 37.8s
# 68:	total: 4.7s	remaining: 37.7s
# 69:	total: 4.76s	remaining: 37.6s
# 70:	total: 4.82s	remaining: 37.5s
# 71:	total: 4.88s	remaining: 37.4s
# 72:	total: 4.95s	remaining: 37.3s
# 73:	total: 5.03s	remaining: 37.4s
# 74:	total: 5.14s	remaining: 37.6s
# 75:	total: 5.22s	remaining: 37.6s
# 76:	total: 5.3s	remaining: 37.6s
# 77:	total: 5.38s	remaining: 37.6s
# 78:	total: 5.44s	remaining: 37.5s
# 79:	total: 5.5s	remaining: 37.3s
# 80:	total: 5.58s	remaining: 37.3s
# 81:	total: 5.64s	remaining: 37.2s
# 82:	total: 5.72s	remaining: 37.2s
# 83:	total: 5.8s	remaining: 37.2s
# 84:	total: 5.88s	remaining: 37.2s
# 85:	total: 5.97s	remaining: 37.3s
# 86:	total: 6.04s	remaining: 37.2s
# 87:	total: 6.11s	remaining: 37.1s
# 88:	total: 6.17s	remaining: 37s
# 89:	total: 6.23s	remaining: 36.9s
# 90:	total: 6.3s	remaining: 36.8s
# 91:	total: 6.38s	remaining: 36.8s
# 92:	total: 6.46s	remaining: 36.8s
# 93:	total: 6.56s	remaining: 36.9s
# 94:	total: 6.63s	remaining: 36.9s
# 95:	total: 6.7s	remaining: 36.8s
# 96:	total: 6.77s	remaining: 36.7s
# 97:	total: 6.83s	remaining: 36.6s
# 98:	total: 6.9s	remaining: 36.5s
# 99:	total: 6.98s	remaining: 36.5s
# 100:	total: 7.04s	remaining: 36.4s
# 101:	total: 7.1s	remaining: 36.2s
# 102:	total: 7.16s	remaining: 36.1s
# 103:	total: 7.23s	remaining: 36.1s
# 104:	total: 7.3s	remaining: 36s
# 105:	total: 7.36s	remaining: 35.9s
# 106:	total: 7.43s	remaining: 35.8s
# 107:	total: 7.49s	remaining: 35.7s
# 108:	total: 7.55s	remaining: 35.6s
# 109:	total: 7.61s	remaining: 35.5s
# 110:	total: 7.67s	remaining: 35.4s
# 111:	total: 7.74s	remaining: 35.3s
# 112:	total: 7.81s	remaining: 35.2s
# 113:	total: 7.87s	remaining: 35.2s
# 114:	total: 7.94s	remaining: 35.1s
# 115:	total: 8s	remaining: 34.9s
# 116:	total: 8.06s	remaining: 34.9s
# 117:	total: 8.12s	remaining: 34.8s
# 118:	total: 8.18s	remaining: 34.7s
# 119:	total: 8.24s	remaining: 34.5s
# 120:	total: 8.3s	remaining: 34.4s
# 121:	total: 8.36s	remaining: 34.3s
# 122:	total: 8.43s	remaining: 34.3s
# 123:	total: 8.49s	remaining: 34.2s
# 124:	total: 8.56s	remaining: 34.1s
# 125:	total: 8.63s	remaining: 34s
# 126:	total: 8.68s	remaining: 33.9s
# 127:	total: 8.75s	remaining: 33.9s
# 128:	total: 8.82s	remaining: 33.8s
# 129:	total: 8.88s	remaining: 33.7s
# 130:	total: 8.94s	remaining: 33.6s
# 131:	total: 8.99s	remaining: 33.5s
# 132:	total: 9.06s	remaining: 33.4s
# 133:	total: 9.13s	remaining: 33.3s
# 134:	total: 9.18s	remaining: 33.2s
# 135:	total: 9.25s	remaining: 33.1s
# 136:	total: 9.31s	remaining: 33s
# 137:	total: 9.39s	remaining: 33s
# 138:	total: 9.44s	remaining: 32.9s
# 139:	total: 9.5s	remaining: 32.8s
# 140:	total: 9.56s	remaining: 32.7s
# 141:	total: 9.62s	remaining: 32.6s
# 142:	total: 9.68s	remaining: 32.5s
# 143:	total: 9.74s	remaining: 32.4s
# 144:	total: 9.81s	remaining: 32.3s
# 145:	total: 9.87s	remaining: 32.3s
# 146:	total: 9.93s	remaining: 32.2s
# 147:	total: 10s	remaining: 32.1s
# 148:	total: 10.1s	remaining: 32s
# 149:	total: 10.1s	remaining: 31.9s
# 150:	total: 10.2s	remaining: 31.9s
# 151:	total: 10.2s	remaining: 31.7s
# 152:	total: 10.3s	remaining: 31.7s
# 153:	total: 10.4s	remaining: 31.6s
# 154:	total: 10.4s	remaining: 31.5s
# 155:	total: 10.5s	remaining: 31.4s
# 156:	total: 10.5s	remaining: 31.3s
# 157:	total: 10.6s	remaining: 31.2s
# 158:	total: 10.7s	remaining: 31.2s
# 159:	total: 10.7s	remaining: 31.1s
# 160:	total: 10.8s	remaining: 31s
# 161:	total: 10.9s	remaining: 31s
# 162:	total: 10.9s	remaining: 30.9s
# 163:	total: 11s	remaining: 30.8s
# 164:	total: 11.1s	remaining: 30.7s
# 165:	total: 11.2s	remaining: 30.7s
# 166:	total: 11.2s	remaining: 30.6s
# 167:	total: 11.3s	remaining: 30.6s
# 168:	total: 11.3s	remaining: 30.5s
# 169:	total: 11.4s	remaining: 30.4s
# 170:	total: 11.5s	remaining: 30.3s
# 171:	total: 11.5s	remaining: 30.2s
# 172:	total: 11.6s	remaining: 30.2s
# 173:	total: 11.7s	remaining: 30.1s
# 174:	total: 11.7s	remaining: 30s
# 175:	total: 11.8s	remaining: 29.9s
# 176:	total: 11.9s	remaining: 29.9s
# 177:	total: 11.9s	remaining: 29.8s
# 178:	total: 12s	remaining: 29.8s
# 179:	total: 12.1s	remaining: 29.7s
# 180:	total: 12.1s	remaining: 29.6s
# 181:	total: 12.2s	remaining: 29.5s
# 182:	total: 12.2s	remaining: 29.4s
# 183:	total: 12.3s	remaining: 29.4s
# 184:	total: 12.4s	remaining: 29.3s
# 185:	total: 12.4s	remaining: 29.2s
# 186:	total: 12.5s	remaining: 29.2s
# 187:	total: 12.6s	remaining: 29.1s
# 188:	total: 12.6s	remaining: 29s
# 189:	total: 12.7s	remaining: 29s
# 190:	total: 12.8s	remaining: 28.9s
# 191:	total: 12.8s	remaining: 28.8s
# 192:	total: 12.9s	remaining: 28.7s
# 193:	total: 13s	remaining: 28.7s
# 194:	total: 13s	remaining: 28.6s
# 195:	total: 13.1s	remaining: 28.5s
# 196:	total: 13.1s	remaining: 28.4s
# 197:	total: 13.2s	remaining: 28.3s
# 198:	total: 13.3s	remaining: 28.3s
# 199:	total: 13.3s	remaining: 28.2s
# 200:	total: 13.4s	remaining: 28.1s
# 201:	total: 13.5s	remaining: 28.1s
# 202:	total: 13.5s	remaining: 28s
# 203:	total: 13.6s	remaining: 27.9s
# 204:	total: 13.7s	remaining: 27.9s
# 205:	total: 13.7s	remaining: 27.8s
# 206:	total: 13.8s	remaining: 27.7s
# 207:	total: 13.8s	remaining: 27.6s
# 208:	total: 13.9s	remaining: 27.5s
# 209:	total: 14s	remaining: 27.5s
# 210:	total: 14s	remaining: 27.4s
# 211:	total: 14.1s	remaining: 27.3s
# 212:	total: 14.2s	remaining: 27.3s
# 213:	total: 14.2s	remaining: 27.2s
# 214:	total: 14.3s	remaining: 27.2s
# 215:	total: 14.4s	remaining: 27.1s
# 216:	total: 14.5s	remaining: 27.1s
# 217:	total: 14.5s	remaining: 27s
# 218:	total: 14.6s	remaining: 27s
# 219:	total: 14.7s	remaining: 26.9s
# 220:	total: 14.8s	remaining: 26.8s
# 221:	total: 14.8s	remaining: 26.8s
# 222:	total: 14.9s	remaining: 26.7s
# 223:	total: 15s	remaining: 26.7s
# 224:	total: 15s	remaining: 26.6s
# 225:	total: 15.1s	remaining: 26.5s
# 226:	total: 15.2s	remaining: 26.5s
# 227:	total: 15.3s	remaining: 26.4s
# 228:	total: 15.3s	remaining: 26.4s
# 229:	total: 15.4s	remaining: 26.3s
# 230:	total: 15.5s	remaining: 26.2s
# 231:	total: 15.5s	remaining: 26.2s
# 232:	total: 15.6s	remaining: 26.1s
# 233:	total: 15.7s	remaining: 26s
# 234:	total: 15.7s	remaining: 26s
# 235:	total: 15.8s	remaining: 25.9s
# 236:	total: 15.8s	remaining: 25.8s
# 237:	total: 15.9s	remaining: 25.8s
# 238:	total: 16s	remaining: 25.7s
# 239:	total: 16.1s	remaining: 25.7s
# 240:	total: 16.1s	remaining: 25.6s
# 241:	total: 16.2s	remaining: 25.5s
# 242:	total: 16.3s	remaining: 25.5s
# 243:	total: 16.4s	remaining: 25.5s
# 244:	total: 16.5s	remaining: 25.4s
# 245:	total: 16.5s	remaining: 25.3s
# 246:	total: 16.6s	remaining: 25.3s
# 247:	total: 16.6s	remaining: 25.2s
# 248:	total: 16.7s	remaining: 25.1s
# 249:	total: 16.8s	remaining: 25s
# 250:	total: 16.8s	remaining: 24.9s
# 251:	total: 16.9s	remaining: 24.9s
# 252:	total: 16.9s	remaining: 24.8s
# 253:	total: 17s	remaining: 24.7s
# 254:	total: 17.1s	remaining: 24.6s
# 255:	total: 17.2s	remaining: 24.6s
# 256:	total: 17.3s	remaining: 24.6s
# 257:	total: 17.4s	remaining: 24.6s
# 258:	total: 17.4s	remaining: 24.5s
# 259:	total: 17.5s	remaining: 24.4s
# 260:	total: 17.6s	remaining: 24.4s
# 261:	total: 17.6s	remaining: 24.3s
# 262:	total: 17.7s	remaining: 24.2s
# 263:	total: 17.7s	remaining: 24.1s
# 264:	total: 17.8s	remaining: 24.1s
# 265:	total: 17.9s	remaining: 24s
# 266:	total: 17.9s	remaining: 23.9s
# 267:	total: 18s	remaining: 23.8s
# 268:	total: 18.1s	remaining: 23.8s
# 269:	total: 18.1s	remaining: 23.7s
# 270:	total: 18.2s	remaining: 23.7s
# 271:	total: 18.3s	remaining: 23.6s
# 272:	total: 18.4s	remaining: 23.6s
# 273:	total: 18.5s	remaining: 23.5s
# 274:	total: 18.6s	remaining: 23.5s
# 275:	total: 18.6s	remaining: 23.4s
# 276:	total: 18.8s	remaining: 23.4s
# 277:	total: 18.8s	remaining: 23.4s
# 278:	total: 18.9s	remaining: 23.3s
# 279:	total: 19s	remaining: 23.3s
# 280:	total: 19.1s	remaining: 23.3s
# 281:	total: 19.2s	remaining: 23.3s
# 282:	total: 19.4s	remaining: 23.3s
# 283:	total: 19.5s	remaining: 23.3s
# 284:	total: 19.6s	remaining: 23.3s
# 285:	total: 19.9s	remaining: 23.4s
# 286:	total: 20.1s	remaining: 23.5s
# 287:	total: 20.3s	remaining: 23.6s
# 288:	total: 20.4s	remaining: 23.6s
# 289:	total: 20.6s	remaining: 23.7s
# 290:	total: 20.7s	remaining: 23.7s
# 291:	total: 20.9s	remaining: 23.7s
# 292:	total: 21s	remaining: 23.7s
# 293:	total: 21.2s	remaining: 23.7s
# 294:	total: 21.3s	remaining: 23.7s
# 295:	total: 21.4s	remaining: 23.7s
# 296:	total: 21.5s	remaining: 23.6s
# 297:	total: 21.6s	remaining: 23.6s
# 298:	total: 21.7s	remaining: 23.6s
# 299:	total: 21.8s	remaining: 23.5s
# 300:	total: 21.9s	remaining: 23.5s
# 301:	total: 22s	remaining: 23.4s
# 302:	total: 22.1s	remaining: 23.4s
# 303:	total: 22.2s	remaining: 23.3s
# 304:	total: 22.3s	remaining: 23.3s
# 305:	total: 22.4s	remaining: 23.2s
# 306:	total: 22.5s	remaining: 23.1s
# 307:	total: 22.6s	remaining: 23.1s
# 308:	total: 22.7s	remaining: 23s
# 309:	total: 22.7s	remaining: 22.9s
# 310:	total: 22.8s	remaining: 22.9s
# 311:	total: 22.8s	remaining: 22.8s
# 312:	total: 22.9s	remaining: 22.7s
# 313:	total: 23s	remaining: 22.6s
# 314:	total: 23s	remaining: 22.5s
# 315:	total: 23.1s	remaining: 22.4s
# 316:	total: 23.2s	remaining: 22.4s
# 317:	total: 23.2s	remaining: 22.3s
# 318:	total: 23.3s	remaining: 22.2s
# 319:	total: 23.3s	remaining: 22.1s
# 320:	total: 23.4s	remaining: 22s
# 321:	total: 23.5s	remaining: 21.9s
# 322:	total: 23.5s	remaining: 21.8s
# 323:	total: 23.6s	remaining: 21.8s
# 324:	total: 23.7s	remaining: 21.7s
# 325:	total: 23.8s	remaining: 21.7s
# 326:	total: 23.9s	remaining: 21.6s
# 327:	total: 24s	remaining: 21.5s
# 328:	total: 24s	remaining: 21.5s
# 329:	total: 24.1s	remaining: 21.4s
# 330:	total: 24.2s	remaining: 21.3s
# 331:	total: 24.2s	remaining: 21.2s
# 332:	total: 24.3s	remaining: 21.2s
# 333:	total: 24.4s	remaining: 21.1s
# 334:	total: 24.4s	remaining: 21s
# 335:	total: 24.5s	remaining: 20.9s
# 336:	total: 24.6s	remaining: 20.9s
# 337:	total: 24.7s	remaining: 20.8s
# 338:	total: 24.8s	remaining: 20.8s
# 339:	total: 24.9s	remaining: 20.7s
# 340:	total: 25s	remaining: 20.6s
# 341:	total: 25s	remaining: 20.6s
# 342:	total: 25.1s	remaining: 20.5s
# 343:	total: 25.2s	remaining: 20.4s
# 344:	total: 25.2s	remaining: 20.3s
# 345:	total: 25.3s	remaining: 20.3s
# 346:	total: 25.4s	remaining: 20.2s
# 347:	total: 25.4s	remaining: 20.1s
# 348:	total: 25.5s	remaining: 20s
# 349:	total: 25.6s	remaining: 20s
# 350:	total: 25.7s	remaining: 19.9s
# 351:	total: 25.7s	remaining: 19.8s
# 352:	total: 25.8s	remaining: 19.7s
# 353:	total: 25.9s	remaining: 19.7s
# 354:	total: 26s	remaining: 19.6s
# 355:	total: 26.1s	remaining: 19.5s
# 356:	total: 26.1s	remaining: 19.5s
# 357:	total: 26.2s	remaining: 19.4s
# 358:	total: 26.3s	remaining: 19.3s
# 359:	total: 26.3s	remaining: 19.2s
# 360:	total: 26.4s	remaining: 19.2s
# 361:	total: 26.5s	remaining: 19.1s
# 362:	total: 26.5s	remaining: 19s
# 363:	total: 26.6s	remaining: 18.9s
# 364:	total: 26.6s	remaining: 18.8s
# 365:	total: 26.7s	remaining: 18.8s
# 366:	total: 26.8s	remaining: 18.7s
# 367:	total: 26.9s	remaining: 18.6s
# 368:	total: 26.9s	remaining: 18.5s
# 369:	total: 27s	remaining: 18.4s
# 370:	total: 27s	remaining: 18.4s
# 371:	total: 27.1s	remaining: 18.3s
# 372:	total: 27.2s	remaining: 18.2s
# 373:	total: 27.3s	remaining: 18.2s
# 374:	total: 27.4s	remaining: 18.1s
# 375:	total: 27.4s	remaining: 18s
# 376:	total: 27.5s	remaining: 17.9s
# 377:	total: 27.6s	remaining: 17.9s
# 378:	total: 27.6s	remaining: 17.8s
# 379:	total: 27.7s	remaining: 17.7s
# 380:	total: 27.8s	remaining: 17.6s
# 381:	total: 27.8s	remaining: 17.6s
# 382:	total: 27.9s	remaining: 17.5s
# 383:	total: 28s	remaining: 17.4s
# 384:	total: 28s	remaining: 17.3s
# 385:	total: 28.1s	remaining: 17.3s
# 386:	total: 28.2s	remaining: 17.2s
# 387:	total: 28.2s	remaining: 17.1s
# 388:	total: 28.3s	remaining: 17s
# 389:	total: 28.4s	remaining: 16.9s
# 390:	total: 28.4s	remaining: 16.9s
# 391:	total: 28.5s	remaining: 16.8s
# 392:	total: 28.5s	remaining: 16.7s
# 393:	total: 28.6s	remaining: 16.6s
# 394:	total: 28.7s	remaining: 16.5s
# 395:	total: 28.7s	remaining: 16.5s
# 396:	total: 28.8s	remaining: 16.4s
# 397:	total: 28.8s	remaining: 16.3s
# 398:	total: 28.9s	remaining: 16.2s
# 399:	total: 28.9s	remaining: 16.1s
# 400:	total: 29s	remaining: 16.1s
# 401:	total: 29.1s	remaining: 16s
# 402:	total: 29.1s	remaining: 15.9s
# 403:	total: 29.2s	remaining: 15.8s
# 404:	total: 29.3s	remaining: 15.8s
# 405:	total: 29.3s	remaining: 15.7s
# 406:	total: 29.4s	remaining: 15.6s
# 407:	total: 29.5s	remaining: 15.5s
# 408:	total: 29.5s	remaining: 15.5s
# 409:	total: 29.6s	remaining: 15.4s
# 410:	total: 29.7s	remaining: 15.3s
# 411:	total: 29.7s	remaining: 15.2s
# 412:	total: 29.8s	remaining: 15.1s
# 413:	total: 29.8s	remaining: 15.1s
# 414:	total: 29.9s	remaining: 15s
# 415:	total: 30s	remaining: 14.9s
# 416:	total: 30.1s	remaining: 14.8s
# 417:	total: 30.1s	remaining: 14.8s
# 418:	total: 30.2s	remaining: 14.7s
# 419:	total: 30.3s	remaining: 14.6s
# 420:	total: 30.3s	remaining: 14.6s
# 421:	total: 30.4s	remaining: 14.5s
# 422:	total: 30.5s	remaining: 14.4s
# 423:	total: 30.5s	remaining: 14.3s
# 424:	total: 30.6s	remaining: 14.3s
# 425:	total: 30.7s	remaining: 14.2s
# 426:	total: 30.7s	remaining: 14.1s
# 427:	total: 30.8s	remaining: 14s
# 428:	total: 30.9s	remaining: 14s
# 429:	total: 30.9s	remaining: 13.9s
# 430:	total: 31s	remaining: 13.8s
# 431:	total: 31.1s	remaining: 13.8s
# 432:	total: 31.2s	remaining: 13.7s
# 433:	total: 31.3s	remaining: 13.6s
# 434:	total: 31.5s	remaining: 13.6s
# 435:	total: 31.6s	remaining: 13.6s
# 436:	total: 31.7s	remaining: 13.5s
# 437:	total: 31.8s	remaining: 13.4s
# 438:	total: 31.9s	remaining: 13.4s
# 439:	total: 32s	remaining: 13.3s
# 440:	total: 32.1s	remaining: 13.2s
# 441:	total: 32.2s	remaining: 13.2s
# 442:	total: 32.3s	remaining: 13.1s
# 443:	total: 32.4s	remaining: 13s
# 444:	total: 32.4s	remaining: 13s
# 445:	total: 32.5s	remaining: 12.9s
# 446:	total: 32.6s	remaining: 12.8s
# 447:	total: 32.6s	remaining: 12.7s
# 448:	total: 32.7s	remaining: 12.7s
# 449:	total: 32.8s	remaining: 12.6s
# 450:	total: 32.9s	remaining: 12.5s
# 451:	total: 33s	remaining: 12.5s
# 452:	total: 33s	remaining: 12.4s
# 453:	total: 33.1s	remaining: 12.3s
# 454:	total: 33.2s	remaining: 12.2s
# 455:	total: 33.2s	remaining: 12.2s
# 456:	total: 33.3s	remaining: 12.1s
# 457:	total: 33.4s	remaining: 12s
# 458:	total: 33.4s	remaining: 11.9s
# 459:	total: 33.5s	remaining: 11.9s
# 460:	total: 33.6s	remaining: 11.8s
# 461:	total: 33.7s	remaining: 11.7s
# 462:	total: 33.7s	remaining: 11.7s
# 463:	total: 33.8s	remaining: 11.6s
# 464:	total: 33.9s	remaining: 11.5s
# 465:	total: 33.9s	remaining: 11.4s
# 466:	total: 34s	remaining: 11.4s
# 467:	total: 34s	remaining: 11.3s
# 468:	total: 34.1s	remaining: 11.2s
# 469:	total: 34.2s	remaining: 11.1s
# 470:	total: 34.3s	remaining: 11.1s
# 471:	total: 34.3s	remaining: 11s
# 472:	total: 34.4s	remaining: 10.9s
# 473:	total: 34.5s	remaining: 10.8s
# 474:	total: 34.5s	remaining: 10.8s
# 475:	total: 34.6s	remaining: 10.7s
# 476:	total: 34.7s	remaining: 10.6s
# 477:	total: 34.7s	remaining: 10.5s
# 478:	total: 34.8s	remaining: 10.5s
# 479:	total: 34.9s	remaining: 10.4s
# 480:	total: 34.9s	remaining: 10.3s
# 481:	total: 35s	remaining: 10.2s
# 482:	total: 35.1s	remaining: 10.2s
# 483:	total: 35.2s	remaining: 10.1s
# 484:	total: 35.3s	remaining: 10s
# 485:	total: 35.3s	remaining: 9.96s
# 486:	total: 35.4s	remaining: 9.88s
# 487:	total: 35.5s	remaining: 9.81s
# 488:	total: 35.5s	remaining: 9.73s
# 489:	total: 35.6s	remaining: 9.66s
# 490:	total: 35.7s	remaining: 9.59s
# 491:	total: 35.7s	remaining: 9.51s
# 492:	total: 35.8s	remaining: 9.44s
# 493:	total: 35.9s	remaining: 9.36s
# 494:	total: 35.9s	remaining: 9.29s
# 495:	total: 36s	remaining: 9.22s
# 496:	total: 36.1s	remaining: 9.15s
# 497:	total: 36.2s	remaining: 9.09s
# 498:	total: 36.3s	remaining: 9.01s
# 499:	total: 36.4s	remaining: 8.95s
# 500:	total: 36.4s	remaining: 8.87s
# 501:	total: 36.5s	remaining: 8.8s
# 502:	total: 36.6s	remaining: 8.73s
# 503:	total: 36.7s	remaining: 8.66s
# 504:	total: 36.7s	remaining: 8.58s
# 505:	total: 36.8s	remaining: 8.51s
# 506:	total: 36.9s	remaining: 8.44s
# 507:	total: 37s	remaining: 8.37s
# 508:	total: 37.1s	remaining: 8.31s
# 509:	total: 37.2s	remaining: 8.24s
# 510:	total: 37.3s	remaining: 8.17s
# 511:	total: 37.4s	remaining: 8.1s
# 512:	total: 37.4s	remaining: 8.03s
# 513:	total: 37.5s	remaining: 7.96s
# 514:	total: 37.6s	remaining: 7.89s
# 515:	total: 37.7s	remaining: 7.82s
# 516:	total: 37.8s	remaining: 7.75s
# 517:	total: 37.9s	remaining: 7.69s
# 518:	total: 38s	remaining: 7.62s
# 519:	total: 38.1s	remaining: 7.55s
# 520:	total: 38.2s	remaining: 7.48s
# 521:	total: 38.3s	remaining: 7.41s
# 522:	total: 38.4s	remaining: 7.35s
# 523:	total: 38.5s	remaining: 7.28s
# 524:	total: 38.6s	remaining: 7.21s
# 525:	total: 38.7s	remaining: 7.14s
# 526:	total: 38.8s	remaining: 7.07s
# 527:	total: 38.9s	remaining: 7s
# 528:	total: 39s	remaining: 6.92s
# 529:	total: 39s	remaining: 6.85s
# 530:	total: 39.1s	remaining: 6.77s
# 531:	total: 39.1s	remaining: 6.69s
# 532:	total: 39.2s	remaining: 6.62s
# 533:	total: 39.3s	remaining: 6.54s
# 534:	total: 39.4s	remaining: 6.47s
# 535:	total: 39.4s	remaining: 6.4s
# 536:	total: 39.5s	remaining: 6.32s
# 537:	total: 39.6s	remaining: 6.25s
# 538:	total: 39.6s	remaining: 6.17s
# 539:	total: 39.7s	remaining: 6.1s
# 540:	total: 39.8s	remaining: 6.03s
# 541:	total: 39.9s	remaining: 5.96s
# 542:	total: 40s	remaining: 5.89s
# 543:	total: 40.1s	remaining: 5.82s
# 544:	total: 40.2s	remaining: 5.75s
# 545:	total: 40.3s	remaining: 5.68s
# 546:	total: 40.3s	remaining: 5.6s
# 547:	total: 40.4s	remaining: 5.53s
# 548:	total: 40.5s	remaining: 5.46s
# 549:	total: 40.6s	remaining: 5.38s
# 550:	total: 40.6s	remaining: 5.31s
# 551:	total: 40.7s	remaining: 5.23s
# 552:	total: 40.8s	remaining: 5.16s
# 553:	total: 40.8s	remaining: 5.09s
# 554:	total: 40.9s	remaining: 5.01s
# 555:	total: 41s	remaining: 4.94s
# 556:	total: 41s	remaining: 4.86s
# 557:	total: 41.1s	remaining: 4.79s
# 558:	total: 41.2s	remaining: 4.71s
# 559:	total: 41.2s	remaining: 4.64s
# 560:	total: 41.3s	remaining: 4.57s
# 561:	total: 41.4s	remaining: 4.49s
# 562:	total: 41.4s	remaining: 4.41s
# 563:	total: 41.5s	remaining: 4.34s
# 564:	total: 41.6s	remaining: 4.26s
# 565:	total: 41.6s	remaining: 4.19s
# 566:	total: 41.7s	remaining: 4.12s
# 567:	total: 41.7s	remaining: 4.04s
# 568:	total: 41.8s	remaining: 3.97s
# 569:	total: 41.9s	remaining: 3.89s
# 570:	total: 41.9s	remaining: 3.82s
# 571:	total: 42s	remaining: 3.74s
# 572:	total: 42.1s	remaining: 3.67s
# 573:	total: 42.2s	remaining: 3.6s
# 574:	total: 42.2s	remaining: 3.53s
# 575:	total: 42.3s	remaining: 3.45s
# 576:	total: 42.4s	remaining: 3.38s
# 577:	total: 42.5s	remaining: 3.31s
# 578:	total: 42.5s	remaining: 3.23s
# 579:	total: 42.6s	remaining: 3.16s
# 580:	total: 42.7s	remaining: 3.08s
# 581:	total: 42.7s	remaining: 3.01s
# 582:	total: 42.8s	remaining: 2.94s
# 583:	total: 42.9s	remaining: 2.86s
# 584:	total: 43s	remaining: 2.79s
# 585:	total: 43.1s	remaining: 2.72s
# 586:	total: 43.2s	remaining: 2.65s
# 587:	total: 43.3s	remaining: 2.58s
# 588:	total: 43.4s	remaining: 2.5s
# 589:	total: 43.5s	remaining: 2.43s
# 590:	total: 43.6s	remaining: 2.36s
# 591:	total: 43.6s	remaining: 2.29s
# 592:	total: 43.7s	remaining: 2.21s
# 593:	total: 43.8s	remaining: 2.14s
# 594:	total: 43.8s	remaining: 2.06s
# 595:	total: 43.9s	remaining: 1.99s
# 596:	total: 44s	remaining: 1.92s
# 597:	total: 44s	remaining: 1.84s
# 598:	total: 44.1s	remaining: 1.77s
# 599:	total: 44.2s	remaining: 1.69s
# 600:	total: 44.3s	remaining: 1.62s
# 601:	total: 44.4s	remaining: 1.55s
# 602:	total: 44.5s	remaining: 1.48s
# 603:	total: 44.5s	remaining: 1.4s
# 604:	total: 44.6s	remaining: 1.33s
# 605:	total: 44.7s	remaining: 1.25s
# 606:	total: 44.8s	remaining: 1.18s
# 607:	total: 44.9s	remaining: 1.11s
# 608:	total: 45s	remaining: 1.03s
# 609:	total: 45s	remaining: 959ms
# 610:	total: 45.1s	remaining: 885ms
# 611:	total: 45.1s	remaining: 812ms
# 612:	total: 45.2s	remaining: 738ms
# 613:	total: 45.3s	remaining: 664ms
# 614:	total: 45.4s	remaining: 591ms
# 615:	total: 45.5s	remaining: 517ms
# 616:	total: 45.5s	remaining: 443ms
# 617:	total: 45.6s	remaining: 369ms
# 618:	total: 45.7s	remaining: 295ms
# 619:	total: 45.8s	remaining: 221ms
# 620:	total: 45.9s	remaining: 148ms
# 621:	total: 46s	remaining: 73.9ms
# 622:	total: 46.1s	remaining: 0us
# BayesSearchCV(cv=StratifiedKFold(n_splits=3, random_state=98, shuffle=True),
#               estimator=Pipeline(steps=[('classifier',
#                                          <catboost.core.CatBoostClassifier object at 0x000001FA45D8DE20>)]),
#               n_iter=10, n_jobs=-1, n_points=5, random_state=98,
#               return_train_score=True, scoring='roc_auc',
#               search_spaces={'classifier__depth': Integer(low=8, high=10, prior='uniform', transform='normalize'),
#                              'classifier__iterations': (500, 1000),
#                              'classifier__l2_leaf_reg': Real(low=0.4, high=0.6, prior='uniform', transform='normalize'),
#                              'classifier__learning_rate': Real(low=0.01, high=0.1, prior='uniform', transform='normalize'),
#                              'classifier__random_strength': Real(low=0.0, high=0.1, prior='uniform', transform='normalize')},
#               verbose=2)

# %%
# Get the best parameters and score
best_params = bayes_search.best_params_
best_score = bayes_search.best_score_
print("Best parameters found: ", best_params)
print("Best cross-validation ROC-AUC score: ", best_score)
# Out:
# Best parameters found:  OrderedDict({'classifier__depth': 9, 'classifier__iterations': 623, 'classifier__l2_leaf_reg': 0.43793371311574664, 'classifier__learning_rate': 0.037485012178841315, 'classifier__random_strength': 0.05603580209043438})
# Best cross-validation ROC-AUC score:  0.8727326642669005

# %%
#check overfitting:
pd.DataFrame(bayes_search.cv_results_)[['rank_test_score','params','mean_train_score','mean_test_score']].sort_values('rank_test_score')[:5]
# Out:
#    rank_test_score  \
# 9                1
# 6                2
# 7                3
# 1                4
# 4                5
#
#                                                                                                                                                                                                            params  \
# 9  {'classifier__depth': 9, 'classifier__iterations': 623, 'classifier__l2_leaf_reg': 0.43793371311574664, 'classifier__learning_rate': 0.037485012178841315, 'classifier__random_strength': 0.05603580209043438}
# 6    {'classifier__depth': 9, 'classifier__iterations': 616, 'classifier__l2_leaf_reg': 0.5865101285079023, 'classifier__learning_rate': 0.03250280110553245, 'classifier__random_strength': 0.02777873535431003}
# 7    {'classifier__depth': 9, 'classifier__iterations': 663, 'classifier__l2_leaf_reg': 0.5717329904576064, 'classifier__learning_rate': 0.03794379778296131, 'classifier__random_strength': 0.04344448993151032}
# 1  {'classifier__depth': 9, 'classifier__iterations': 845, 'classifier__l2_leaf_reg': 0.5195772293414612, 'classifier__learning_rate': 0.040448024867092106, 'classifier__random_strength': 0.010838067961221413}
# 4   {'classifier__depth': 9, 'classifier__iterations': 516, 'classifier__l2_leaf_reg': 0.5836880807473535, 'classifier__learning_rate': 0.06363838103610073, 'classifier__random_strength': 0.010675738936071603}
#
#    mean_train_score  mean_test_score
# 9             0.898            0.873
# 6             0.894            0.873
# 7             0.900            0.873
# 1             0.909            0.872
# 4             0.908            0.872

# %%
# Evaluate the final model with the best parameters
y_pred = bayes_search.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_pred)
print("Test ROC-AUC score: ", roc_auc)
# Out:
# Test ROC-AUC score:  0.87564346641206

# %%
#Test ROC-AUC score: 0.877
#Not so close to 0.882, best results so far. Let's submit even though.
#Kaggle public: 0.825: overfitted!

#-----------
#Test ROC-AUC score:  0.875 - when setting parameters closer to best so far. Not submitted.

# %% [markdown]
# # Kaggle Submission

# %%
print(test.shape) #7 MI rows!
test[:3]
# Out:
# (7669866, 15)
#          id  gender  age  driving_license  region_code  previously_insured  \
# 0  11504798       1   20                1           47                   0
# 1  11504799       0   47                1           28                   0
# 2  11504800       0   47                1           43                   0
#
#    vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  vintage  \
# 0            0               0            2630                   160      228
# 1            1               1           37483                   124      123
# 2            1               1            2630                    26      271
#
#    previously_insured_annual_premium  previously_insured_vehicle_age  \
# 0                                  3                               1
# 1                              22988                               0
# 2                                  3                               0
#
#    previously_insured_vehicle_damage  previously_insured_vintage
# 0                                  1                         244
# 1                                  0                         266
# 2                                  0                         420

# %%
#drop response col (added on data cleaning)
test.drop(columns='response', inplace=True)

# %%
#predict on prod data:
y_hat_prod = bayes_search.predict_proba(test)[:,1]

# %%
#save id to build submission file
test_id = test['id'].copy()

# %%
#Predictions done:
print(y_hat_prod.shape)
y_hat_prod[:5]
# Out:
# (7669866,)
# array([0.003202, 0.299115, 0.227925, 0.01966 , 0.067216])

# %%
# Prepare for submission: id + predictions:
# Create final dataset
df_sub = pd.concat([ pd.Series(test_id, name='id') , pd.Series(y_hat_prod, name='Target') ], axis=1)
df_sub[:3]
# Out:
#          id  Target
# 0  11504798   0.003
# 1  11504799   0.299
# 2  11504800   0.228

# %%
# Export to submit on Kaggle
df_sub.to_parquet('..\\data\\v9\\submission_v9.parquet', engine='pyarrow')
